# %%
from pathlib import Path
import pandas as pd
#print(os.path.dirname(os.path.abspath(__file__)))
#csv_path = str(Path(__file__).resolve().parents[0].joinpath('data', 'NBA-Play-by-Play Data_Sample', 'sample-combined-pbp-stats.csv'))
csv_path = str(Path('.').joinpath('data', 'NBA-Play-by-Play Data_Sample', 'sample-combined-pbp-stats.csv'))
print(csv_path)
pbp = pd.read_csv(csv_path)
# print(list(pbp.keys()))
#print(pbp['event_type'].value_counts())
print(pbp[(pbp['event_type'] == 'shot') & (pbp['result'] == 'made')][['player', 'points', 'result', 'shot_distance']])
# Out:
# data/NBA-Play-by-Play Data_Sample/sample-combined-pbp-stats.csv
#                 player  points result  shot_distance
# 2         Kyrie Irving     2.0   made           10.0
# 11          Al Horford     2.0   made           20.0
# 14         Jae Crowder     2.0   made           22.0
# 17         Dwyane Wade     2.0   made           12.0
# 20        Derrick Rose     2.0   made            1.0
# 22      Gordon Hayward     2.0   made            9.0
# 32        Kyrie Irving     2.0   made           16.0
# 34        Jaylen Brown     2.0   made            2.0
# 46        Jaylen Brown     2.0   made            1.0
# 56        LeBron James     2.0   made           22.0
# 57        Kyrie Irving     2.0   made           16.0
# 58        Derrick Rose     2.0   made            1.0
# 67        LeBron James     2.0   made            1.0
# 68        Jaylen Brown     2.0   made            1.0
# 73    Tristan Thompson     2.0   made            0.0
# ...

# %%
from pathlib import Path
import pandas as pd
csv_path = "data/NBA-Play-by-Play Data_Sample/sample-combined-pbp-stats.csv"
pbp = pd.read_csv(csv_path)
pbp['event_type'].value_counts()
# Out:
# rebound            532
# miss               486
# shot               419
# free throw         241
# foul               221
# sub                221
# turnover           147
# timeout             55
# end of period       20
# start of period     20
# violation           12
# unknown              7
# jump ball            5
# Name: event_type, dtype: int64

# %%
from pathlib import Path
import pandas as pd
csv_path = str(Path('.').joinpath('data', 'NBA-Play-by-Play Data_Sample', '(2016-06-10)-0041500404-GSW@CLE.csv'))
print(csv_path)
pbp = pd.read_csv(csv_path)
print(pbp['event_type'].value_counts())
# Out:
# data/NBA-Play-by-Play Data_Sample/(2016-06-10)-0041500404-GSW@CLE.csv
# rebound                                                                         108
# miss                                                                             91
# shot                                                                             71
# free throw                                                                       57
# foul                                                                             47
# sub                                                                              43
# turnover                                                                         20
# timeout                                                                          16
# end of period                                                                     4
# start of period                                                                   4
# ...

# %%
pbp.head()
# Out:
#                            game_id                               data_set  \
# 0  Official \nGame ID \nat NBA.com  Season that this data sets belongs to
# 1                         41500404                           2016 Playoff
# 2                         41500404                           2016 Playoff
# 3                         41500404                           2016 Playoff
# 4                         41500404                           2016 Playoff
#
#         date                                                 a1  \
# 0  Game date  First player of away team who is one of  the a...
# 1    6/10/16                                    Harrison Barnes
# 2    6/10/16                                    Harrison Barnes
# 3    6/10/16                                    Harrison Barnes
# 4    6/10/16                                    Harrison Barnes
#
#                                                   a2  \
# 0  Second player of away team who is one of  the ...
# ...

# %%
print(pbp[(pbp['event_type'] == 'shot') & (pbp['result'] == 'made')][['player', 'points', 'result', 'shot_distance']])
# Out:
#                    player points result shot_distance
# 5         Harrison Barnes      3   made            23
# 6            Kyrie Irving      3   made            24
# 10             J.R. Smith      3   made            23
# 11        Harrison Barnes      2   made            14
# 14       Tristan Thompson      2   made             4
# 15        Harrison Barnes      3   made            23
# 16       Tristan Thompson      2   made             1
# 38           Kyrie Irving      3   made            24
# 40          Klay Thompson      3   made            25
# 42         Draymond Green      2   made             1
# 45       Tristan Thompson      2   made             5
# 49          Klay Thompson      2   made             0
# 54           Kyrie Irving      2   made             9
# 63           LeBron James      2   made             1
# 64          Stephen Curry      3   made            25
# 67             Kevin Love      2   made             0
# ...

# %%
pbp[(pbp['event_type'] == 'shot') & (pbp['result'] == 'made')][['player', 'points', 'result', 'shot_distance']]
# Out:
#                    player points result shot_distance
# 5         Harrison Barnes      3   made            23
# 6            Kyrie Irving      3   made            24
# 10             J.R. Smith      3   made            23
# 11        Harrison Barnes      2   made            14
# 14       Tristan Thompson      2   made             4
# 15        Harrison Barnes      3   made            23
# 16       Tristan Thompson      2   made             1
# 38           Kyrie Irving      3   made            24
# 40          Klay Thompson      3   made            25
# 42         Draymond Green      2   made             1
# 45       Tristan Thompson      2   made             5
# 49          Klay Thompson      2   made             0
# 54           Kyrie Irving      2   made             9
# 63           LeBron James      2   made             1
# 64          Stephen Curry      3   made            25
# 67             Kevin Love      2   made             0
# ...

# %%
pbp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 44 columns):
# game_id           468 non-null object
# data_set          468 non-null object
# date              468 non-null object
# a1                468 non-null object
# a2                468 non-null object
# a3                468 non-null object
# a4                468 non-null object
# a5                468 non-null object
# h1                468 non-null object
# h2                468 non-null object
# h3                468 non-null object
# h4                468 non-null object
# h5                468 non-null object
# period            468 non-null object
# away_score        468 non-null object
# home_score        468 non-null object
# remaining_time    468 non-null object
# elapsed           468 non-null object
# play_length       468 non-null object
# play_id           468 non-null object
# team              415 non-null object
# event_type        468 non-null object
# ...

# %%
pbp['event_type'].value_counts()
# Out:
# rebound                                                                         108
# miss                                                                             91
# shot                                                                             71
# free throw                                                                       57
# foul                                                                             47
# sub                                                                              43
# turnover                                                                         20
# timeout                                                                          16
# end of period                                                                     4
# start of period                                                                   4
# jump ball                                                                         3
# ...

# %%
pbp['type'].value_counts()
# Out:
# Jump Shot                           79
# rebound defensive                   53
# sub                                 43
# rebound offensive                   30
# Free Throw 2 of 2                   26
# Free Throw 1 of 2                   26
# team rebound                        25
# p.foul                              23
# Driving Layup                       22
# s.foul                              16
# Pullup Jump Shot                    14
# unknown                             11
#  timeout: regular                   11
# Layup                               10
# bad pass                             8
# out of bounds lost ball turnover     5
# Step Back Jump Shot                  4
# end of period                        4
# Turnaround Jump Shot                 4
# lost ball                            4
# start of period                      4
#  timeout: short                      3
# Jump Bank Shot                       3
# l.b.foul                             3
# ...

# %%
25+53+30
# Out:
# 108

# %%
print(pbp[(pbp['type'] == 'rebound offensive')]['player'])
# Out:
# 4          Harrison Barnes
# 13        Tristan Thompson
# 44        Tristan Thompson
# 51        Tristan Thompson
# 66              Kevin Love
# 82        Tristan Thompson
# 90        Tristan Thompson
# 101        Harrison Barnes
# 112       Shaun Livingston
# 118    Matthew Dellavedova
# 139      Richard Jefferson
# 141      Richard Jefferson
# 159         Draymond Green
# 168          Stephen Curry
# 207           LeBron James
# 250           Andrew Bogut
# 271           LeBron James
# 279        Harrison Barnes
# 283          Stephen Curry
# 309           LeBron James
# 317       Anderson Varejao
# 319       Anderson Varejao
# 328       Anderson Varejao
# 351           LeBron James
# 358          Iman Shumpert
# 371           Kyrie Irving
# 379       Tristan Thompson
# 383          Stephen Curry
# 392         Andre Iguodala
# 407         Andre Iguodala
# Name: player, dtype: object

# %%
pbp[(pbp['type'] == 'rebound offensive')]['player'].value_counts()
# Out:
# Tristan Thompson       6
# LeBron James           4
# Stephen Curry          3
# Harrison Barnes        3
# Anderson Varejao       3
# Richard Jefferson      2
# Andre Iguodala         2
# Kyrie Irving           1
# Matthew Dellavedova    1
# Andrew Bogut           1
# Kevin Love             1
# Shaun Livingston       1
# Iman Shumpert          1
# Draymond Green         1
# Name: player, dtype: int64

# %%
pbp.head(10)
# Out:
#                            game_id                               data_set  \
# 0  Official \nGame ID \nat NBA.com  Season that this data sets belongs to
# 1                         41500404                           2016 Playoff
# 2                         41500404                           2016 Playoff
# 3                         41500404                           2016 Playoff
# 4                         41500404                           2016 Playoff
# 5                         41500404                           2016 Playoff
# 6                         41500404                           2016 Playoff
# 7                         41500404                           2016 Playoff
# 8                         41500404                           2016 Playoff
# 9                         41500404                           2016 Playoff
#
#         date                                                 a1  \
# 0  Game date  First player of away team who is one of  the a...
# ...

# %%
pbp.head(400)
# Out:
#                              game_id                               data_set  \
# 0    Official \nGame ID \nat NBA.com  Season that this data sets belongs to
# 1                           41500404                           2016 Playoff
# 2                           41500404                           2016 Playoff
# 3                           41500404                           2016 Playoff
# 4                           41500404                           2016 Playoff
# 5                           41500404                           2016 Playoff
# 6                           41500404                           2016 Playoff
# 7                           41500404                           2016 Playoff
# 8                           41500404                           2016 Playoff
# 9                           41500404                           2016 Playoff
# 10                          41500404                           2016 Playoff
# ...

# %%
pbp
# Out:
#                              game_id                               data_set  \
# 0    Official \nGame ID \nat NBA.com  Season that this data sets belongs to
# 1                           41500404                           2016 Playoff
# 2                           41500404                           2016 Playoff
# 3                           41500404                           2016 Playoff
# 4                           41500404                           2016 Playoff
# 5                           41500404                           2016 Playoff
# 6                           41500404                           2016 Playoff
# 7                           41500404                           2016 Playoff
# 8                           41500404                           2016 Playoff
# 9                           41500404                           2016 Playoff
# 10                          41500404                           2016 Playoff
# ...

# %%
pbp.loc[pbp['play_id']=='5']
# Out:
#     game_id      data_set     date               a1              a2  \
# 6  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
#
#              a3             a4             a5                 h1  \
# 6  Andrew Bogut  Klay Thompson  Stephen Curry  Richard Jefferson
#
#              h2                       ...                       reason result  \
# 6  LeBron James                       ...                          NaN   made
#
#   steal       type shot_distance original_x original_y converted_x  \
# 6   NaN  Jump Shot            24       -240        -19           1
#
#   converted_y                                     explanation
# 6        90.9  Irving 24' 3PT Jump Shot (3 PTS) (James 1 AST)
#
# [1 rows x 44 columns]

# %%
pbp.columns
# Out:
# Index(['game_id', 'data_set', 'date', 'a1', 'a2', 'a3', 'a4', 'a5', 'h1', 'h2',
#        'h3', 'h4', 'h5', 'period', 'away_score', 'home_score',
#        'remaining_time', 'elapsed', 'play_length', 'play_id', 'team',
#        'event_type', 'assist', 'away', 'home', 'block', 'entered', 'left',
#        'num', 'opponent', 'outof', 'player', 'points', 'possession', 'reason',
#        'result', 'steal', 'type', 'shot_distance', 'original_x', 'original_y',
#        'converted_x', 'converted_y', 'explanation'],
#       dtype='object')

# %%
pbp.columns
# Out:
# Index(['game_id', 'data_set', 'date', 'a1', 'a2', 'a3', 'a4', 'a5', 'h1', 'h2',
#        'h3', 'h4', 'h5', 'period', 'away_score', 'home_score',
#        'remaining_time', 'elapsed', 'play_length', 'play_id', 'team',
#        'event_type', 'assist', 'away', 'home', 'block', 'entered', 'left',
#        'num', 'opponent', 'outof', 'player', 'points', 'possession', 'reason',
#        'result', 'steal', 'type', 'shot_distance', 'original_x', 'original_y',
#        'converted_x', 'converted_y', 'explanation'],
#       dtype='object')

# %%
pbp.loc[pbp['play_id']=='5']
# Out:
#     game_id      data_set     date               a1              a2  \
# 6  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
#
#              a3             a4             a5                 h1  \
# 6  Andrew Bogut  Klay Thompson  Stephen Curry  Richard Jefferson
#
#              h2                       ...                       reason result  \
# 6  LeBron James                       ...                          NaN   made
#
#   steal       type shot_distance original_x original_y converted_x  \
# 6   NaN  Jump Shot            24       -240        -19           1
#
#   converted_y                                     explanation
# 6        90.9  Irving 24' 3PT Jump Shot (3 PTS) (James 1 AST)
#
# [1 rows x 44 columns]

# %%
pbp
# Out:
#                              game_id                               data_set  \
# 0    Official \nGame ID \nat NBA.com  Season that this data sets belongs to
# 1                           41500404                           2016 Playoff
# 2                           41500404                           2016 Playoff
# 3                           41500404                           2016 Playoff
# 4                           41500404                           2016 Playoff
# 5                           41500404                           2016 Playoff
# 6                           41500404                           2016 Playoff
# 7                           41500404                           2016 Playoff
# 8                           41500404                           2016 Playoff
# 9                           41500404                           2016 Playoff
# 10                          41500404                           2016 Playoff
# ...

# %%
pbp.columns
# Out:
# Index(['game_id', 'data_set', 'date', 'a1', 'a2', 'a3', 'a4', 'a5', 'h1', 'h2',
#        'h3', 'h4', 'h5', 'period', 'away_score', 'home_score',
#        'remaining_time', 'elapsed', 'play_length', 'play_id', 'team',
#        'event_type', 'assist', 'away', 'home', 'block', 'entered', 'left',
#        'num', 'opponent', 'outof', 'player', 'points', 'possession', 'reason',
#        'result', 'steal', 'type', 'shot_distance', 'original_x', 'original_y',
#        'converted_x', 'converted_y', 'explanation'],
#       dtype='object')

# %%
pbp.loc[pbp['play_id']=='6']
# Out:
#     game_id      data_set     date               a1              a2  \
# 7  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
#
#              a3             a4             a5                 h1  \
# 7  Andrew Bogut  Klay Thompson  Stephen Curry  Richard Jefferson
#
#              h2                 ...                  reason result steal  \
# 7  LeBron James                 ...                  s.foul    NaN   NaN
#
#      type shot_distance original_x original_y converted_x converted_y  \
# 7  s.foul           NaN        NaN        NaN         NaN         NaN
#
#                           explanation
# 7  Irving S.FOUL (P1.T1) (J.Phillips)
#
# [1 rows x 44 columns]

# %%
pbp
# Out:
#                              game_id                               data_set  \
# 0    Official \nGame ID \nat NBA.com  Season that this data sets belongs to
# 1                           41500404                           2016 Playoff
# 2                           41500404                           2016 Playoff
# 3                           41500404                           2016 Playoff
# 4                           41500404                           2016 Playoff
# 5                           41500404                           2016 Playoff
# 6                           41500404                           2016 Playoff
# 7                           41500404                           2016 Playoff
# 8                           41500404                           2016 Playoff
# 9                           41500404                           2016 Playoff
# 10                          41500404                           2016 Playoff
# ...

# %%
pbp
# Out:
#                              game_id                               data_set  \
# 0    Official \nGame ID \nat NBA.com  Season that this data sets belongs to
# 1                           41500404                           2016 Playoff
# 2                           41500404                           2016 Playoff
# 3                           41500404                           2016 Playoff
# 4                           41500404                           2016 Playoff
# 5                           41500404                           2016 Playoff
# 6                           41500404                           2016 Playoff
# 7                           41500404                           2016 Playoff
# 8                           41500404                           2016 Playoff
# 9                           41500404                           2016 Playoff
# 10                          41500404                           2016 Playoff
# ...

# %%
pbp.loc[pbp['play_id']=='5']
# Out:
#     game_id      data_set     date               a1              a2  \
# 6  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
#
#              a3             a4             a5                 h1  \
# 6  Andrew Bogut  Klay Thompson  Stephen Curry  Richard Jefferson
#
#              h2                       ...                       reason result  \
# 6  LeBron James                       ...                          NaN   made
#
#   steal       type shot_distance original_x original_y converted_x  \
# 6   NaN  Jump Shot            24       -240        -19           1
#
#   converted_y                                     explanation
# 6        90.9  Irving 24' 3PT Jump Shot (3 PTS) (James 1 AST)
#
# [1 rows x 44 columns]

# %%
pbp.describe()
# Out:
#          game_id      data_set     date               a1              a2  \
# count        468           468      468              468             468
# unique         2             2        2                5               5
# top     41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# freq         467           467      467              259             160
#
#                     a3             a4             a5            h1  \
# count              468            468            468           468
# unique              11             11             11             4
# top     Andre Iguodala  Klay Thompson  Stephen Curry  LeBron James
# freq               185             81            164           318
#
#                 h2        ...          reason result         steal       type  \
# count          468        ...              66    220            13        468
# unique           9        ...              13      3             8         51
# ...

# %%
pbp.iloc[6:20]
# Out:
#      game_id      data_set     date               a1              a2  \
# 6   41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 7   41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 8   41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 9   41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 10  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 11  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 12  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 13  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 14  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 15  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 16  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 17  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# 18  41500404  2016 Playoff  6/10/16  Harrison Barnes  Draymond Green
# ...

# %%
print('Hello World')
print(2)
# Out:
# Hello World
# 2

# %%
dp=pd.read_csv('data/NBA-Play-by-Play Data_Sample/sample-combined-pbp-stats.csv')

# %%
import pandas as pd
dp=pd.read_csv('data/NBA-Play-by-Play Data_Sample/sample-combined-pbp-stats.csv')

# %%
dp
# Out:
#        game_id                  data_set        date              a1  \
# 0     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 1     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 2     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 3     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 4     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 5     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 6     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 7     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 8     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 9     21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 10    21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 11    21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 12    21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# ...

# %%
dp.head()
# Out:
#     game_id                  data_set        date              a1  \
# 0  21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 1  21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 2  21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 3  21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
# 4  21700001  2017-2018 Regular Season  10/17/2017  Gordon Hayward
#
#              a2          a3            a4            a5            h1  \
# 0  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving  LeBron James
# 1  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving  LeBron James
# 2  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving  LeBron James
# 3  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving  LeBron James
# 4  Jayson Tatum  Al Horford  Jaylen Brown  Kyrie Irving  LeBron James
#
#             h2                        ...                         reason  \
# ...

# %%
pbp
# Out:
#                              game_id                               data_set  \
# 0    Official \nGame ID \nat NBA.com  Season that this data sets belongs to
# 1                           41500404                           2016 Playoff
# 2                           41500404                           2016 Playoff
# 3                           41500404                           2016 Playoff
# 4                           41500404                           2016 Playoff
# 5                           41500404                           2016 Playoff
# 6                           41500404                           2016 Playoff
# 7                           41500404                           2016 Playoff
# 8                           41500404                           2016 Playoff
# 9                           41500404                           2016 Playoff
# 10                          41500404                           2016 Playoff
# ...

# %%
print(pbp['event_type'].value_counts())
print(pbp[(pbp['event_type'] == 'shot') & (pbp['result'] == 'made')][['player', 'points', 'result', 'shot_distance']])
# Out:
# rebound                                                                         108
# miss                                                                             91
# shot                                                                             71
# free throw                                                                       57
# foul                                                                             47
# sub                                                                              43
# turnover                                                                         20
# timeout                                                                          16
# end of period                                                                     4
# start of period                                                                   4
# jump ball                                                                         3
# ...

# %%
b_points = pbp[pbp['result'] == 'made']['points']
b_distance = pbp[pbp['result'] == 'made']['shot_distance']

# %%
b_points
# Out:
# 5      3
# 6      3
# 8      1
# 9      1
# 10     3
# 11     2
# 14     2
# 15     3
# 16     2
# 38     3
# 40     3
# 42     2
# 45     2
# 49     2
# 54     2
# 57     1
# 63     2
# 64     3
# 67     2
# 69     1
# 72     1
# 79     1
# 80     1
# 83     2
# 84     3
# 86     1
# 87     1
# 88     2
# 94     1
# 99     1
#       ..
# 339    1
# 345    2
# 348    2
# 349    2
# 352    2
# 353    3
# 360    2
# 369    2
# 376    1
# 384    2
# 393    3
# 413    2
# 414    3
# 424    2
# 434    1
# 437    2
# 440    2
# 447    1
# 449    1
# 450    2
# 452    1
# 453    1
# 454    2
# 456    1
# 457    1
# 458    2
# 460    1
# 461    1
# 465    1
# 466    1
# Name: points, Length: 111, dtype: object

# %%
b_points
# Out:
# 5      3
# 6      3
# 8      1
# 9      1
# 10     3
# 11     2
# 14     2
# 15     3
# 16     2
# 38     3
# 40     3
# 42     2
# 45     2
# 49     2
# 54     2
# 57     1
# 63     2
# 64     3
# 67     2
# 69     1
# 72     1
# 79     1
# 80     1
# 83     2
# 84     3
# 86     1
# 87     1
# 88     2
# 94     1
# 99     1
#       ..
# 339    1
# 345    2
# 348    2
# 349    2
# 352    2
# 353    3
# 360    2
# 369    2
# 376    1
# 384    2
# 393    3
# 413    2
# 414    3
# 424    2
# 434    1
# 437    2
# 440    2
# 447    1
# 449    1
# 450    2
# 452    1
# 453    1
# 454    2
# 456    1
# 457    1
# 458    2
# 460    1
# 461    1
# 465    1
# 466    1
# Name: points, Length: 111, dtype: object

# %%
from bokeh.plotting import figure, output_file, show

# output to static HTML file
output_file("line.html")

p = figure(plot_width=500, plot_height=500, y_range=(0, 30), x_range=(0,4))

# add a circle renderer with a size, color, and alpha
p.circle(b_points, b_distance, color="navy", alpha=0.5)

# show the results
show(p)

# %%
b_distance.value_counts()
# Out:
# 1     12
# 0     11
# 25    10
# 2      6
# 24     6
# 23     5
# 14     4
# 15     3
# 18     2
# 8      2
# 16     2
# 26     2
# 27     1
# 9      1
# 5      1
# 13     1
# 4      1
# 17     1
# Name: shot_distance, dtype: int64

# %%
b_points.value_counts()
# Out:
# 2    48
# 1    40
# 3    23
# Name: points, dtype: int64

# %%
from bokeh.plotting import figure, output_file, show

# output to static HTML file
output_file("line.html")

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=2.5)

# show the results
show(p)
